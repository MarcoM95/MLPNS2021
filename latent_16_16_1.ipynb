# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcoM95/MLPNS2021/blob/main/latent_16_16_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from keras.datasets import cifar10
from keras.layers import Input, Dense,Conv2D,MaxPooling2D,UpSampling2D,BatchNormalization,Dropout,Flatten,Conv2DTranspose
from keras.models import Model,Sequential
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
(X_train, train_labels), (X_test, test_labels) = cifar10.load_data()
X_train = X_train.astype('float32') / 255
X_test  = X_test.astype('float32') / 255
X_train = X_train.reshape(len(X_train),X_train.shape[1],X_train.shape[2],3)
X_test  = X_test.reshape(len(X_test), X_test.shape[1],X_test.shape[2],3)
print('Train images shape:',X_train.shape)
print('Test images shape:',X_test.shape)

print('(max,min)=', X_train.min(), X_train.max())
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 8s 0us/step
# 170508288/170498071 [==============================] - 8s 0us/step
# Train images shape: (50000, 32, 32, 3)
# Test images shape: (10000, 32, 32, 3)
# (max,min)= 0.0 1.0

# %% [markdown]
# # 16x16x1

# %%
input_img = Input(shape=(32,32,3))

#Encoder
x = Conv2D(32, 3, activation='relu', padding='same')(input_img)
x = BatchNormalization()(x)
x = MaxPooling2D(2, padding='same')(x)

x = Conv2D(1, 3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)

# Bottleneck
encoded = x

#Decoder
#x = UpSampling2D((2,2))(encoded)
x = Conv2DTranspose(32, 3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = UpSampling2D((2,2))(x)
x = Conv2DTranspose(32, 3, activation='relu', padding='same')(x)
x = BatchNormalization()(x)

decoded = Conv2DTranspose(3, 1, activation='sigmoid', padding='same')(x)

autoencoder_model_16_16_1 = Model(input_img, decoded)
autoencoder_model_16_16_1.compile(optimizer='adam', loss='mse')

autoencoder_model_16_16_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 1)         289
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 1)         4
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 16, 16, 32)        320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 32)        128
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 32)        9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 32, 32, 3)         99
# =================================================================
# Total params: 11,240
# Trainable params: 11,046
# Non-trainable params: 194
# _________________________________________________________________

# %%
encoder_model_16_16_1 = Model(input_img, encoded)
encoder_model_16_16_1.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 1)         289
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 16, 1)         4
# =================================================================
# Total params: 1,317
# Trainable params: 1,251
# Non-trainable params: 66
# _________________________________________________________________

# %%
autoencoder_model_16_16_1.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

er = EarlyStopping(monitor='val_loss', patience=10)
callbacks = [er]

history_AE_16_16_1 = autoencoder_model_16_16_1.fit(X_train, X_train,
                    epochs=30,
                    batch_size=512,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    callbacks=callbacks)
# Out:
# Epoch 1/30
# 98/98 [==============================] - 39s 92ms/step - loss: 0.0296 - accuracy: 0.3798 - val_loss: 0.0603 - val_accuracy: 0.4105
# Epoch 2/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0114 - accuracy: 0.4118 - val_loss: 0.0549 - val_accuracy: 0.4183
# Epoch 3/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0093 - accuracy: 0.4432 - val_loss: 0.0386 - val_accuracy: 0.4740
# Epoch 4/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0086 - accuracy: 0.4579 - val_loss: 0.0269 - val_accuracy: 0.4668
# Epoch 5/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0083 - accuracy: 0.4656 - val_loss: 0.0185 - val_accuracy: 0.4655
# Epoch 6/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0080 - accuracy: 0.4711 - val_loss: 0.0134 - val_accuracy: 0.4604
# Epoch 7/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0079 - accuracy: 0.4767 - val_loss: 0.0108 - val_accuracy: 0.4679
# Epoch 8/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0078 - accuracy: 0.4803 - val_loss: 0.0092 - val_accuracy: 0.4856
# Epoch 9/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0077 - accuracy: 0.4847 - val_loss: 0.0084 - val_accuracy: 0.4776
# Epoch 10/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0076 - accuracy: 0.4875 - val_loss: 0.0081 - val_accuracy: 0.4797
# Epoch 11/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0076 - accuracy: 0.4878 - val_loss: 0.0079 - val_accuracy: 0.4826
# Epoch 12/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0075 - accuracy: 0.4910 - val_loss: 0.0076 - val_accuracy: 0.4890
# Epoch 13/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0074 - accuracy: 0.4916 - val_loss: 0.0074 - val_accuracy: 0.4943
# Epoch 14/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0074 - accuracy: 0.4945 - val_loss: 0.0074 - val_accuracy: 0.4926
# Epoch 15/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0074 - accuracy: 0.4966 - val_loss: 0.0073 - val_accuracy: 0.5012
# Epoch 16/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0073 - accuracy: 0.4980 - val_loss: 0.0072 - val_accuracy: 0.4995
# Epoch 17/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0073 - accuracy: 0.4997 - val_loss: 0.0072 - val_accuracy: 0.4981
# Epoch 18/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0072 - accuracy: 0.5002 - val_loss: 0.0073 - val_accuracy: 0.5081
# Epoch 19/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0072 - accuracy: 0.5024 - val_loss: 0.0072 - val_accuracy: 0.5021
# Epoch 20/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0072 - accuracy: 0.5026 - val_loss: 0.0072 - val_accuracy: 0.5122
# Epoch 21/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0072 - accuracy: 0.5040 - val_loss: 0.0071 - val_accuracy: 0.5073
# Epoch 22/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0072 - accuracy: 0.5049 - val_loss: 0.0072 - val_accuracy: 0.5109
# Epoch 23/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0071 - accuracy: 0.5062 - val_loss: 0.0072 - val_accuracy: 0.5150
# Epoch 24/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0071 - accuracy: 0.5080 - val_loss: 0.0072 - val_accuracy: 0.5183
# Epoch 25/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0071 - accuracy: 0.5132 - val_loss: 0.0074 - val_accuracy: 0.5051
# Epoch 26/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0070 - accuracy: 0.5200 - val_loss: 0.0073 - val_accuracy: 0.5086
# Epoch 27/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0070 - accuracy: 0.5276 - val_loss: 0.0074 - val_accuracy: 0.5104
# Epoch 28/30
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0070 - accuracy: 0.5317 - val_loss: 0.0074 - val_accuracy: 0.5070
# Epoch 29/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0069 - accuracy: 0.5337 - val_loss: 0.0072 - val_accuracy: 0.5237
# Epoch 30/30
# 98/98 [==============================] - 8s 83ms/step - loss: 0.0069 - accuracy: 0.5352 - val_loss: 0.0071 - val_accuracy: 0.5204

# %%
plt.plot(np.array(history_AE_16_16_1.history['loss']), label="train_loss")
plt.plot(np.array(history_AE_16_16_1.history['val_loss']), label="val_loss")
plt.ylabel('loss')
plt.xlabel('iteration')
plt.legend()
#plt.savefig('loss_AE.png')
#plt.yscale('log')
#plt.xscale('log')

# %%
scores = autoencoder_model_16_16_1.evaluate(X_test,X_test,verbose=1)
print("Test Loss",scores[0])
print("Test Accuracy",scores[1])
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0071 - accuracy: 0.5204
# Test Loss 0.007104620337486267
# Test Accuracy 0.5204080939292908

# %%
from numpy import asarray
from numpy import savetxt

loss_AE_16_16_1 = asarray(history_AE_16_16_1.history['loss'])
# save to csv file
savetxt('loss_AE_16_16_1.csv', loss_AE_16_16_1, delimiter=',')

val_loss_AE_16_16_1 = asarray(history_AE_16_16_1.history['val_loss'])
# save to csv file
savetxt('val_loss_AE_16_16_1.csv', val_loss_AE_16_16_1, delimiter=',')

# %%
reconstructed_test_images_16_16_1 = autoencoder_model_16_16_1.predict(X_test)
print(reconstructed_test_images_16_16_1.shape)
# Out:
# (10000, 32, 32, 3)

# %%
def mse(imageA, imageB):
	# the 'Mean Squared Error' between the two images is the
	# sum of the squared difference between the two images;
	# NOTE: the two images must have the same dimension
	err = np.sum((imageA.astype("float") - imageB.astype("float")) ** 2)
	err /= float(imageA.shape[0] * imageA.shape[1])
	
	# return the MSE, the lower the error, the more "similar"
	# the two images are
	return err

# %%
print(mse(X_test[0],reconstructed_test_images_16_16_1[0]))
print(mse(X_test[10],reconstructed_test_images_16_16_1[10]))
print(mse(X_test[100],reconstructed_test_images_16_16_1[100]))
# Out:
# 0.04421340965129035
# 0.020116807972277134
# 0.010407771149703083

# %%
mse_vec_16_16_1 = np.zeros(X_test.shape[0])
for x in range(X_test.shape[0]):
  mse_vec_16_16_1[x] = mse(X_test[x],reconstructed_test_images_16_16_1[x])

import numpy as np

print(mse_vec_16_16_1.shape)
print(np.mean(mse_vec_16_16_1))
# Out:
# (10000,)
# 0.02131385954863136

# %%
plt.figure(figsize=(40,4))
for i in range(10):
    # display original images
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(X_test[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # display reconstructed images
    ax = plt.subplot(3, 20, 2*20 +i+ 1)
    plt.imshow(reconstructed_test_images_16_16_1[i].reshape(32, 32,3))
    #plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
def classifier_conv(inp):
    input = Input((inp.shape[1], inp.shape[2], inp.shape[3]))
    
    #x = Conv2D(32, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(input)
    x = Conv2D(64, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(input)
    x = BatchNormalization()(x)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.5)(x)
    
    #x = Conv2D(64, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(x)
    x = Conv2D(128, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.5)(x)
    
    x = Flatten()(x)
    x = Dense(512, kernel_initializer='he_uniform', activation='relu')(x)
    x = Dropout(0.35)(x)
    x = Dense(100, kernel_initializer='he_uniform', activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(10, activation='softmax')(x)
    return Model(input, output)

# %%
'''
def classifier_conv(inp):
    input = Input((inp.shape[1], inp.shape[2], inp.shape[3]))
    
    x = UpSampling2D((2,2))(input)
    x = Conv2D(64, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(x)
    x = BatchNormalization()(x)
    #x = MaxPooling2D(2)(x)
    x = Dropout(0.5)(x)
    
    #x = UpSampling2D((2,2))(x)
    x = Conv2D(128, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.5)(x)
    
    x = Conv2D(128, 3, kernel_initializer='he_uniform', padding="same",activation='relu')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(2)(x)
    x = Dropout(0.5)(x)
    
    x = Flatten()(x)
    x = Dense(512, kernel_initializer='he_uniform', activation='relu')(x)
    x = Dropout(0.35)(x)
    x = Dense(100, kernel_initializer='he_uniform', activation='relu')(x)
    x = Dropout(0.5)(x)
    output = Dense(10, activation='softmax')(x)
    return Model(input, output)
'''
# Out:
# '\ndef classifier_conv(inp):\n    input = Input((inp.shape[1], inp.shape[2], inp.shape[3]))\n    \n    x = UpSampling2D((2,2))(input)\n    x = Conv2D(64, 3, kernel_initializer=\'he_uniform\', padding="same",activation=\'relu\')(x)\n    x = BatchNormalization()(x)\n    #x = MaxPooling2D(2)(x)\n    x = Dropout(0.5)(x)\n    \n    #x = UpSampling2D((2,2))(x)\n    x = Conv2D(128, 3, kernel_initializer=\'he_uniform\', padding="same",activation=\'relu\')(x)\n    x = BatchNormalization()(x)\n    x = MaxPooling2D(2)(x)\n    x = Dropout(0.5)(x)\n    \n    x = Conv2D(128, 3, kernel_initializer=\'he_uniform\', padding="same",activation=\'relu\')(x)\n    x = BatchNormalization()(x)\n    x = MaxPooling2D(2)(x)\n    x = Dropout(0.5)(x)\n    \n    x = Flatten()(x)\n    x = Dense(512, kernel_initializer=\'he_uniform\', activation=\'relu\')(x)\n    x = Dropout(0.35)(x)\n    x = Dense(100, kernel_initializer=\'he_uniform\', activation=\'relu\')(x)\n    x = Dropout(0.5)(x)\n    output = Dense(10, activation=\'softmax\')(x)\n    return Model(input, output)\n'

# %%
encoded_imgs_train_16_16_1 = encoder_model_16_16_1.predict(X_train)
print(encoded_imgs_train_16_16_1.shape)
# Out:
# (50000, 16, 16, 1)

# %%
encoded_imgs_test_16_16_1 = encoder_model_16_16_1.predict(X_test)
print(encoded_imgs_test_16_16_1.shape)
# Out:
# (10000, 16, 16, 1)

# %%
classifier_16_16_1 = classifier_conv(encoded_imgs_train_16_16_1)
classifier_16_16_1.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 16, 16, 1)]       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        640
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               51300
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 1,176,662
# Trainable params: 1,176,278
# Non-trainable params: 384
# _________________________________________________________________

# %%
import keras
from tensorflow.keras.optimizers import Adam # - Works
opt = Adam(learning_rate=0.001)

classifier_16_16_1.compile(optimizer=opt, loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])  # binary_crossentropy

# %%
from keras.utils import np_utils

train_labels_categorical = keras.utils.np_utils.to_categorical(train_labels, 10)
test_labels_categorical  = keras.utils.np_utils.to_categorical(test_labels, 10)

print(train_labels_categorical.shape)
print(test_labels_categorical.shape)
# Out:
# (50000, 10)
# (10000, 10)

# %%
history_class_16_16_1 = classifier_16_16_1.fit(encoded_imgs_train_16_16_1, train_labels_categorical, batch_size=64, epochs=30,
                    validation_data=(encoded_imgs_test_16_16_1, test_labels_categorical))
# Out:
# Epoch 1/30
# 782/782 [==============================] - 9s 10ms/step - loss: 2.2662 - accuracy: 0.1603 - val_loss: 1.8994 - val_accuracy: 0.2855
# Epoch 2/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.9171 - accuracy: 0.2837 - val_loss: 1.6793 - val_accuracy: 0.3959
# Epoch 3/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.7529 - accuracy: 0.3568 - val_loss: 1.5844 - val_accuracy: 0.4362
# Epoch 4/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.6399 - accuracy: 0.4079 - val_loss: 1.4584 - val_accuracy: 0.4846
# Epoch 5/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.5664 - accuracy: 0.4415 - val_loss: 1.3851 - val_accuracy: 0.4927
# Epoch 6/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.5073 - accuracy: 0.4661 - val_loss: 1.3074 - val_accuracy: 0.5291
# Epoch 7/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.4545 - accuracy: 0.4907 - val_loss: 1.3176 - val_accuracy: 0.5377
# Epoch 8/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.4159 - accuracy: 0.5035 - val_loss: 1.2576 - val_accuracy: 0.5631
# Epoch 9/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.3735 - accuracy: 0.5237 - val_loss: 1.1808 - val_accuracy: 0.5840
# Epoch 10/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.3390 - accuracy: 0.5351 - val_loss: 1.1488 - val_accuracy: 0.6040
# Epoch 11/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.3136 - accuracy: 0.5443 - val_loss: 1.1551 - val_accuracy: 0.6036
# Epoch 12/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2864 - accuracy: 0.5570 - val_loss: 1.1185 - val_accuracy: 0.6092
# Epoch 13/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2642 - accuracy: 0.5643 - val_loss: 1.0757 - val_accuracy: 0.6316
# Epoch 14/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2365 - accuracy: 0.5760 - val_loss: 1.0609 - val_accuracy: 0.6333
# Epoch 15/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.2144 - accuracy: 0.5829 - val_loss: 1.0764 - val_accuracy: 0.6298
# Epoch 16/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1994 - accuracy: 0.5882 - val_loss: 1.0617 - val_accuracy: 0.6366
# Epoch 17/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1786 - accuracy: 0.5952 - val_loss: 1.0339 - val_accuracy: 0.6441
# Epoch 18/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1665 - accuracy: 0.5989 - val_loss: 1.0221 - val_accuracy: 0.6446
# Epoch 19/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1490 - accuracy: 0.6022 - val_loss: 1.0258 - val_accuracy: 0.6462
# Epoch 20/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1344 - accuracy: 0.6117 - val_loss: 1.0078 - val_accuracy: 0.6561
# Epoch 21/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1210 - accuracy: 0.6154 - val_loss: 0.9745 - val_accuracy: 0.6654
# Epoch 22/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.1022 - accuracy: 0.6222 - val_loss: 1.0242 - val_accuracy: 0.6517
# Epoch 23/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0954 - accuracy: 0.6246 - val_loss: 0.9887 - val_accuracy: 0.6628
# Epoch 24/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0788 - accuracy: 0.6305 - val_loss: 1.0078 - val_accuracy: 0.6588
# Epoch 25/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0738 - accuracy: 0.6321 - val_loss: 0.9751 - val_accuracy: 0.6668
# Epoch 26/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0576 - accuracy: 0.6379 - val_loss: 0.9914 - val_accuracy: 0.6609
# Epoch 27/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0455 - accuracy: 0.6409 - val_loss: 0.9473 - val_accuracy: 0.6756
# Epoch 28/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0393 - accuracy: 0.6432 - val_loss: 0.9473 - val_accuracy: 0.6785
# Epoch 29/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0216 - accuracy: 0.6503 - val_loss: 0.9361 - val_accuracy: 0.6818
# Epoch 30/30
# 782/782 [==============================] - 8s 10ms/step - loss: 1.0151 - accuracy: 0.6534 - val_loss: 0.9420 - val_accuracy: 0.6785

# %%
# Loss curve
plt.figure(figsize=[6,4])
plt.plot(history_class_16_16_1.history['loss'], 'black', linewidth=2.0)
plt.plot(history_class_16_16_1.history['val_loss'], 'green', linewidth=2.0)
plt.legend(['Training Loss', 'Validation Loss'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Loss', fontsize=10)
plt.title('Loss Curves', fontsize=12)

# Accuracy curve
plt.figure(figsize=[6,4])
plt.plot(history_class_16_16_1.history['accuracy'], 'black', linewidth=2.0)
plt.plot(history_class_16_16_1.history['val_accuracy'], 'blue', linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=14)
plt.xlabel('Epochs', fontsize=10)
plt.ylabel('Accuracy', fontsize=10)
plt.title('Accuracy Curves', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
loss_class_16_16_1 = asarray(history_class_16_16_1.history['loss'])
# save to csv file
savetxt('loss_class_16_16_1.csv', loss_class_16_16_1, delimiter=',')

val_loss_class_16_16_1 = asarray(history_class_16_16_1.history['val_loss'])
# save to csv file
savetxt('val_loss_class_16_16_1.csv', val_loss_class_16_16_1, delimiter=',')

# %%
accuracy_class_16_16_1 = asarray(history_class_16_16_1.history['accuracy'])
# save to csv file
savetxt('accuracy_class_16_16_1.csv', accuracy_class_16_16_1, delimiter=',')

val_accuracy_class_16_16_1 = asarray(history_class_16_16_1.history['val_accuracy'])
# save to csv file
savetxt('val_accuracy_class_16_16_1.csv', val_accuracy_class_16_16_1, delimiter=',')

# %%
scores = classifier_16_16_1.evaluate(encoded_imgs_test_16_16_1,test_labels_categorical,verbose=1)
print("Test Loss",scores[0])
print("Test Accuracy",scores[1])
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9420 - accuracy: 0.6785
# Test Loss 0.9420141577720642
# Test Accuracy 0.6784999966621399
